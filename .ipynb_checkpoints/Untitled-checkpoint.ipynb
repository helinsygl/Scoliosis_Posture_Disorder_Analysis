# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
print("GPU listesi:", gpus)
print("GPU var mı?", len(gpus) > 0)
# Out:
# GPU listesi: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')]
# GPU var mı? True

# %%
import torch
import torchvision
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
#   Cell In[4], line 1
#     echo $CUDA_HOME
#          ^
# SyntaxError: invalid syntax
